# %%
import pulp
from pulp import *
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
prob=LpProblem("Facility Location Problem - Single Sourcing Case",LpMinimize)

# %%
#Create the variables
x11= LpVariable( 'x11', lowBound=0,cat='Continuous')
x12= LpVariable( 'x12', lowBound=0,cat='Continuous')
x13= LpVariable( 'x13', lowBound=0,cat='Continuous')
x14= LpVariable( 'x14', lowBound=0,cat='Continuous')
x15= LpVariable( 'x15', lowBound=0,cat='Continuous')
x16= LpVariable( 'x16', lowBound=0,cat='Continuous')
x17= LpVariable( 'x17', lowBound=0,cat='Continuous')
x18= LpVariable( 'x18', lowBound=0,cat='Continuous')
x19= LpVariable( 'x19', lowBound=0,cat='Continuous')
x110= LpVariable( 'x110', lowBound=0,cat='Continuous')
x21= LpVariable ( 'x21', lowBound=0,cat='Continuous')
x22= LpVariable( 'x22', lowBound=0,cat='Continuous')
x23= LpVariable ( 'x23', lowBound=0,cat='Continuous')
x24= LpVariable ( 'x24', lowBound=0,cat='Continuous')
x25= LpVariable ( 'x25', lowBound=0,cat='Continuous')
x26= LpVariable ( 'x26', lowBound=0,cat='Continuous')
x27= LpVariable ( 'x27', lowBound=0,cat='Continuous')
x28= LpVariable ( 'x28', lowBound=0,cat='Continuous')
x29= LpVariable ( 'x29', lowBound=0,cat='Continuous')
x210= LpVariable ( 'x210', lowBound=0,cat='Continuous')
x31= LpVariable ( 'x31', lowBound=0,cat='Continuous')
x32= LpVariable ( 'x32', lowBound=0,cat='Continuous')
x33= LpVariable( 'x33', lowBound=0,cat='Continuous')
x34= LpVariable ( 'x34', lowBound=0,cat='Continuous')
x35= LpVariable ( 'x35', lowBound=0,cat='Integer')
x36= LpVariable ( 'x36', lowBound=0,cat='Integer')
x37= LpVariable ( 'x37', lowBound=0,cat='Integer')
x38= LpVariable ( 'x38', lowBound=0,cat='Integer')
x39= LpVariable ( 'x39', lowBound=0,cat='Integer')
x310= LpVariable ( 'x310', lowBound=0,cat='Integer')
x41= LpVariable ( 'x41' ,lowBound=0,cat='Integer')
x42= LpVariable ( 'x42', lowBound=0,cat='Integer')
x43= LpVariable ( 'x43', lowBound=0,cat='Integer')
x44= LpVariable( 'x44', lowBound=0,cat='Integer')
x45= LpVariable ( 'x45', lowBound=0,cat='Integer')
x46= LpVariable ( 'x46', lowBound=0,cat='Integer')
x47= LpVariable ( 'x47', lowBound=0,cat='Integer')
x48= LpVariable ( 'x48', lowBound=0,cat='Integer')
x49= LpVariable ( 'x49', lowBound=0,cat='Integer')
x410= LpVariable ('x410', lowBound=0,cat='Integer')
x51= LpVariable ( 'x51', lowBound=0,cat='Integer')
x52= LpVariable ( 'x52', lowBound=0,cat='Integer')
x53= LpVariable ( 'x53', lowBound=0,cat='Integer')
x54= LpVariable ( 'x54', lowBound=0,cat='Integer')
x55= LpVariable( 'x55', lowBound=0,cat='Integer')
x56= LpVariable ( 'x56', lowBound=0,cat='Integer')
x57= LpVariable ( 'x57', lowBound=0,cat='Integer')
x58= LpVariable ( 'x58', lowBound=0,cat='Integer')
x59= LpVariable ( 'x59', lowBound=0,cat='Integer')
x510= LpVariable ('x510', lowBound=0,cat='Integer')
x61= LpVariable ( 'x61', lowBound=0,cat='Integer')
x62= LpVariable ( 'x62', lowBound=0,cat='Integer')
x63= LpVariable ( 'x63', lowBound=0,cat='Integer')
x64= LpVariable ( 'x64', lowBound=0,cat='Integer')
x65= LpVariable ( 'x65', lowBound=0,cat='Integer')
x66= LpVariable( 'x66', lowBound=0,cat='Integer')
x67= LpVariable ( 'x67', lowBound=0,cat='Integer')
x68= LpVariable ( 'x68', lowBound=0,cat='Integer')
x69= LpVariable ( 'x69', lowBound=0,cat='Integer')
x610= LpVariable ('x610', lowBound=0,cat='Integer')


y1= LpVariable ( 'y1', lowBound=0,cat='Binary')
y2= LpVariable ( 'y2', lowBound=0,cat='Binary')
y3= LpVariable ( 'y3', lowBound=0,cat='Binary')
y4= LpVariable ( 'y4', lowBound=0,cat='Binary')
y5= LpVariable ( 'y5', lowBound=0,cat='Binary')
y6= LpVariable ( 'y6', lowBound=0,cat='Binary')
d1=25
d2=15
d3=20
d4=10
d5=15
d6=15
d7=25
d8=20
d9=30
d10=20

# %%
prob+=1750000*y1+1800000*y2+3000000*y3+2250000*y4+1500000*y5+1000000*y6+d1*(3*x11+5*x21+8*x31+12*x41+10*x51+11*x61)+d2*(6*x12+7*x22+10*x32+12*x42+8*x52+10*x62)+d3*(5*x13+3*x23+8*x33+10*x43+12*x53+10*x63)+d4*(7*x14+6*x24+7*x34+10*x44+9*x54+5*x64)+d5*(10*x15+8*x25+5*x35+8*x45+6*x55+5*x65)+d6*(12*x16+6*x26+4*x36+7*x46+5*x56+4*x66)+d7*(7*x17+10*x27+6*x37+6*x47+8*x57+3*x67)+d8*(5*x18+6*x28+9*x38+4*x48+4*x58+7*x68)+d9*(8*x19+10*x29+7*x39+5*x49+4*x59+6*x69)+d10*(10*x110+12*x210+8*x310+3*x410+4*x510+6*x610)
prob+=25*x11+15*x12+20*x13+10*x14+15*x15+15*x16+25*x17+20*x18+30*x19+20*x110<=75*y1
prob+=25*x21+15*x22+20*x23+10*x24+15*x25+15*x26+25*x27+20*x28+30*x29+20*x210<=50*y2
prob+=25*x31+15*x32+20*x33+10*x34+15*x35+15*x36+25*x37+20*x38+30*x39+20*x310<=120*y3
prob+=25*x41+15*x42+20*x43+10*x44+15*x45+15*x46+25*x47+20*x48+30*x49+20*x410<=100*y4
prob+=25*x51+15*x52+20*x53+10*x54+15*x55+15*x56+25*x57+20*x58+30*x59+20*x510<=60*y5
prob+=25*x61+15*x62+20*x63+10*x64+15*x65+15*x66+25*x67+20*x68+30*x69+20*x610<=50*y6
prob+=x11+x21+x31+x41+x51+x61==1
prob+=x12+x22+x32+x42+x52+x62==1
prob+=x13+x23+x33+x43+x53+x63==1
prob+=x14+x24+x34+x44+x54+x64==1
prob+=x15+x25+x35+x45+x55+x65==1
prob+=x16+x26+x36+x46+x56+x66==1
prob+=x17+x27+x37+x47+x57+x67==1
prob+=x18+x28+x38+x48+x58+x68==1
prob+=x19+x29+x39+x49+x59+x69==1
prob+=x110+x210+x310+x410+x510+x610==1
print(prob)
# Out:
# Facility Location Problem - Single Sourcing Case:
# MINIMIZE
# 75*x11 + 200*x110 + 90*x12 + 100*x13 + 70*x14 + 150*x15 + 180*x16 + 175*x17 + 100*x18 + 240*x19 + 125*x21 + 240*x210 + 105*x22 + 60*x23 + 60*x24 + 120*x25 + 90*x26 + 250*x27 + 120*x28 + 300*x29 + 200*x31 + 160*x310 + 150*x32 + 160*x33 + 70*x34 + 75*x35 + 60*x36 + 150*x37 + 180*x38 + 210*x39 + 300*x41 + 60*x410 + 180*x42 + 200*x43 + 100*x44 + 120*x45 + 105*x46 + 150*x47 + 80*x48 + 150*x49 + 250*x51 + 80*x510 + 120*x52 + 240*x53 + 90*x54 + 90*x55 + 75*x56 + 200*x57 + 80*x58 + 120*x59 + 275*x61 + 120*x610 + 150*x62 + 200*x63 + 50*x64 + 75*x65 + 60*x66 + 75*x67 + 140*x68 + 180*x69 + 1750000*y1 + 1800000*y2 + 3000000*y3 + 2250000*y4 + 1500000*y5 + 1000000*y6 + 0
# SUBJECT TO
# _C1: 25 x11 + 20 x110 + 15 x12 + 20 x13 + 10 x14 + 15 x15 + 15 x16 + 25 x17
#  + 20 x18 + 30 x19 - 75 y1 <= 0
#
# _C2: 25 x21 + 20 x210 + 15 x22 + 20 x23 + 10 x24 + 15 x25 + 15 x26 + 25 x27
#  + 20 x28 + 30 x29 - 50 y2 <= 0
#
# ...

# %%
prob.solve()
print("Status:", LpStatus[prob.status])
# Out:
# Status: Optimal

# %%
print ('Optimal objective value:',value(prob.objective))
# Out:
# Optimal objective value: 4751135.0
